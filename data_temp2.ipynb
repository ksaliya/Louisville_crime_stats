# %%
import pandas as pd

# %%
df = pd.DataFrame()
for year in range(2007, 2018):
    temp = pd.read_csv('crime-data-All-2018-07-22_0030/Crime_Data_{}.csv'.format(year))
    df = df.append(temp)
# Out:
# C:\Users\Saliya\AppData\Local\Programs\Python\Python36\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (906072, 15)

# %%
df.columns
# Out:
# Index(['INCIDENT_NUMBER', 'DATE_REPORTED', 'DATE_OCCURED', 'UOR_DESC',
#        'CRIME_TYPE', 'NIBRS_CODE', 'UCR_HIERARCHY', 'ATT_COMP',
#        'LMPD_DIVISION', 'LMPD_BEAT', 'PREMISE_TYPE', 'BLOCK_ADDRESS', 'CITY',
#        'ZIP_CODE', 'ID'],
#       dtype='object')

# %%
df['CRIME_TYPE'].value_counts()
# Out:
# THEFT/LARCENY               163953
# DRUGS/ALCOHOL VIOLATIONS    156019
# OTHER                       129183
# ASSAULT                     126415
# BURGLARY                     77009
# VANDALISM                    69238
# VEHICLE BREAK-IN/THEFT       65839
# FRAUD                        40393
# MOTOR VEHICLE THEFT          32579
# ROBBERY                      17764
# WEAPONS                      10193
# DISTURBING THE PEACE          8619
# SEX CRIMES                    7312
# HOMICIDE                       832
# DUI                            630
# ARSON                           94
# Name: CRIME_TYPE, dtype: int64

# %%
df.head(2)
# Out:
#   INCIDENT_NUMBER        DATE_REPORTED         DATE_OCCURED  \
# 0    80-07-110000  2007-02-15 03:00:00  2007-02-15 03:00:00
# 1    80-07-077775  2007-10-10 05:50:00  2007-10-10 05:50:00
#
#                               UOR_DESC                CRIME_TYPE NIBRS_CODE  \
# 0  RECEIVING STOLEN PROPERTY (FIREARM)             THEFT/LARCENY        280
# 1                    POSS OF MARIJUANA  DRUGS/ALCOHOL VIOLATIONS        35A
#
#   UCR_HIERARCHY   ATT_COMP LMPD_DIVISION LMPD_BEAT            PREMISE_TYPE  \
# 0       PART II  COMPLETED  1ST DIVISION       112         OTHER / UNKNOWN
# 1       PART II  COMPLETED  5TH DIVISION       514  HIGHWAY / ROAD / ALLEY
#
#                                        BLOCK_ADDRESS        CITY ZIP_CODE  \
# 0  2200 BLOCK MAGAZINE ST                        ...  LOUISVILLE    40211
# 1  EMERSON AVE / BARDSTOWN RD                    ...  LOUISVILLE    40205
#
#        ID
# 0  172217
# 1  175143

# %%
df['YEAR_REPORTED'] = [df['DATE_REPORTED'].iloc[i].split('-')[0] for i in range(0, len(df))]

# %%
df.head(2)
# Out:
#   INCIDENT_NUMBER        DATE_REPORTED         DATE_OCCURED  \
# 0    80-07-110000  2007-02-15 03:00:00  2007-02-15 03:00:00
# 1    80-07-077775  2007-10-10 05:50:00  2007-10-10 05:50:00
#
#                               UOR_DESC                CRIME_TYPE NIBRS_CODE  \
# 0  RECEIVING STOLEN PROPERTY (FIREARM)             THEFT/LARCENY        280
# 1                    POSS OF MARIJUANA  DRUGS/ALCOHOL VIOLATIONS        35A
#
#   UCR_HIERARCHY   ATT_COMP LMPD_DIVISION LMPD_BEAT            PREMISE_TYPE  \
# 0       PART II  COMPLETED  1ST DIVISION       112         OTHER / UNKNOWN
# 1       PART II  COMPLETED  5TH DIVISION       514  HIGHWAY / ROAD / ALLEY
#
#                                        BLOCK_ADDRESS        CITY ZIP_CODE  \
# 0  2200 BLOCK MAGAZINE ST                        ...  LOUISVILLE    40211
# 1  EMERSON AVE / BARDSTOWN RD                    ...  LOUISVILLE    40205
#
#        ID YEAR_REPORTED
# 0  172217          2007
# 1  175143          2007

# %%
df['MONTH_REPORTED'] = [df['DATE_REPORTED'].iloc[i].split('-')[1] for i in range(0, len(df))]
df['DAY_REPORTED'] = [df['DATE_REPORTED'].iloc[i].split('-')[2].split()[0] for i in range(0, len(df))]

# df['YEAR_OCCURED'] = [df['DATE_OCCURED'].iloc[i].split('-')[0] for i in range(0, len(df))]
# df['MONTH_OCCURED'] = [df['DATE_OCCURED'].iloc[i].split('-')[1] for i in range(0, len(df))]
# df['DAY_OCCURED'] = [df['DATE_OCCURED'].iloc[i].split('-')[2].split()[0] for i in range(0, len(df))]

# df['DATE_REPORTED'].iloc[0].split('-')[2].split()[0]

# %%
df.head(2)
# Out:
#   INCIDENT_NUMBER        DATE_REPORTED         DATE_OCCURED  \
# 0    80-07-110000  2007-02-15 03:00:00  2007-02-15 03:00:00
# 1    80-07-077775  2007-10-10 05:50:00  2007-10-10 05:50:00
#
#                               UOR_DESC                CRIME_TYPE NIBRS_CODE  \
# 0  RECEIVING STOLEN PROPERTY (FIREARM)             THEFT/LARCENY        280
# 1                    POSS OF MARIJUANA  DRUGS/ALCOHOL VIOLATIONS        35A
#
#   UCR_HIERARCHY   ATT_COMP LMPD_DIVISION LMPD_BEAT            PREMISE_TYPE  \
# 0       PART II  COMPLETED  1ST DIVISION       112         OTHER / UNKNOWN
# 1       PART II  COMPLETED  5TH DIVISION       514  HIGHWAY / ROAD / ALLEY
#
#                                        BLOCK_ADDRESS        CITY ZIP_CODE  \
# 0  2200 BLOCK MAGAZINE ST                        ...  LOUISVILLE    40211
# 1  EMERSON AVE / BARDSTOWN RD                    ...  LOUISVILLE    40205
#
#        ID YEAR_REPORTED MONTH_REPORTED DAY_REPORTED
# ...

# %%
name = ['YEAR_OCCURED', 'MONTH_OCCURED', 'DAY_OCCURED']
for j in range(0, len(name)):
    temp = []
    for i in range(0, len(df)):
        try:
            if j != 2:
                temp.append(df['DATE_OCCURED'].iloc[i].split('-')[j])
            else:
                temp.append(df['DATE_OCCURED'].iloc[i].split('-')[j].split()[0])
        except:
            temp.append('NaN')
    df[name[j]] = temp

# %%
df.head(2)
# Out:
#   INCIDENT_NUMBER        DATE_REPORTED         DATE_OCCURED  \
# 0    80-07-110000  2007-02-15 03:00:00  2007-02-15 03:00:00
# 1    80-07-077775  2007-10-10 05:50:00  2007-10-10 05:50:00
#
#                               UOR_DESC                CRIME_TYPE NIBRS_CODE  \
# 0  RECEIVING STOLEN PROPERTY (FIREARM)             THEFT/LARCENY        280
# 1                    POSS OF MARIJUANA  DRUGS/ALCOHOL VIOLATIONS        35A
#
#   UCR_HIERARCHY   ATT_COMP LMPD_DIVISION LMPD_BEAT     ...      \
# 0       PART II  COMPLETED  1ST DIVISION       112     ...
# 1       PART II  COMPLETED  5TH DIVISION       514     ...
#
#                                        BLOCK_ADDRESS        CITY ZIP_CODE  \
# 0  2200 BLOCK MAGAZINE ST                        ...  LOUISVILLE    40211
# 1  EMERSON AVE / BARDSTOWN RD                    ...  LOUISVILLE    40205
#
#        ID  YEAR_REPORTED MONTH_REPORTED DAY_REPORTED YEAR_OCCURED  \
# 0  172217           2007             02           15         2007
# ...

# %%
df_types_of_crimes = pd.DataFrame(df['CRIME_TYPE'].value_counts().reset_index())
df_types_of_crimes.columns = ['CRIME_TYPE', 'TOTAL_COUNTS']
df_types_of_crimes
# Out:
#                   CRIME_TYPE  TOTAL_COUNTS
# 0              THEFT/LARCENY        163953
# 1   DRUGS/ALCOHOL VIOLATIONS        156019
# 2                      OTHER        129183
# 3                    ASSAULT        126415
# 4                   BURGLARY         77009
# 5                  VANDALISM         69238
# 6     VEHICLE BREAK-IN/THEFT         65839
# 7                      FRAUD         40393
# 8        MOTOR VEHICLE THEFT         32579
# 9                    ROBBERY         17764
# 10                   WEAPONS         10193
# 11      DISTURBING THE PEACE          8619
# 12                SEX CRIMES          7312
# 13                  HOMICIDE           832
# 14                       DUI           630
# 15                     ARSON            94

# %%
# df.groupby(['YEAR_REPORTED', 'CRIME_TYPE']).size().reset_index(name='COUNTS')

# %%
crimes_reported_by_year = pd.crosstab(df.YEAR_REPORTED,df.CRIME_TYPE)

# %%
crimes_occured_by_year = pd.crosstab(df.YEAR_OCCURED,df.CRIME_TYPE)

# %%
crimes_reported_by_year
# Out:
# CRIME_TYPE     ARSON  ASSAULT  BURGLARY  DISTURBING THE PEACE  \
# YEAR_REPORTED
# 2007              12     8417      7892                  2578
# 2008              13     9169      7304                  1706
# 2009              10     9221      7141                   670
# 2010               3    10345      7610                   496
# 2011              10    10489      8080                   428
# 2012               4    12938      7148                   484
# 2013               9    11923      7042                   476
# 2014              13    12319      6570                   415
# 2015               4    13384      6418                   490
# 2016              11    14193      6085                   536
# 2017               5    14017      5719                   340
#
# CRIME_TYPE     DRUGS/ALCOHOL VIOLATIONS  DUI  FRAUD  HOMICIDE  \
# YEAR_REPORTED
# 2007                              15731  315   3820        78
# 2008                              12605  214   3534        75
# ...

# %%
# crimes_reported_by_year.stack().reset_index().rename(columns={0:'value'}) # this is same as grouping by two columns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(15,10))  
for i in range(0, len(crimes_reported_by_year.columns)):
    plt.plot(crimes_reported_by_year.index.values, crimes_reported_by_year[crimes_reported_by_year.columns[i]])

plt.legend(loc='best', bbox_to_anchor=(1, 1))
plt.title('Number of crimes by category over 10 years')
plt.xlabel('Year')
plt.ylabel('Crime count')
plt.show()

# %%
crimes_reported_by_year.describe()
# Out:
# CRIME_TYPE      ARSON       ASSAULT     BURGLARY  DISTURBING THE PEACE  \
# count       11.000000     11.000000    11.000000             11.000000
# mean         8.545455  11492.272727  7000.818182            783.545455
# std          3.830500   2062.578682   739.725059            704.080587
# min          3.000000   8417.000000  5719.000000            340.000000
# 25%          4.500000   9783.000000  6494.000000            452.000000
# 50%         10.000000  11923.000000  7141.000000            490.000000
# 75%         11.500000  13161.000000  7457.000000            603.000000
# max         13.000000  14193.000000  8080.000000           2578.000000
#
# CRIME_TYPE  DRUGS/ALCOHOL VIOLATIONS         DUI        FRAUD    HOMICIDE  \
# count                      11.000000   11.000000    11.000000   11.000000
# mean                    14183.545455   57.272727  3672.090909   75.636364
# std                      1139.087035  105.220807   564.124712   21.768200
# ...

# %%
df.head(2)

# %%
from sklearn import preprocessing

# %%
crimes_reported_by_year_normalized = crimes_reported_by_year

# %%
min_max_scalar = preprocessing.MinMaxScaler()

for i in range(0, len(crimes_reported_by_year_normalized.columns)):
# for i in range(0, 2):
    temp_floats = crimes_reported_by_year_normalized[crimes_reported_by_year_normalized.columns[i]].values.astype(float)
    scaled_array = min_max_scalar.fit_transform(temp_floats)
    crimes_reported_by_year_normalized[crimes_reported_by_year_normalized.columns[i]] = scaled_array

crimes_reported_by_year_normalized.head(5)
# Out:
# C:\Users\Saliya\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\preprocessing\data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# C:\Users\Saliya\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\preprocessing\data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# ...

# %%
for i in range(0, len(crimes_reported_by_year_normalized.columns)):
    plt.plot(crimes_reported_by_year_normalized.index.values, crimes_reported_by_year[crimes_reported_by_year_normalized.columns[i]])
plt.show()

# %%
 import seaborn as sns

# %%
# now stack and reset
stacked = crimes_reported_by_year_normalized.stack().reset_index().rename(columns={0:'value'})

# plot grouped bar chart
fig, ax = plt.subplots(figsize=(15,10))
sns.barplot(x=stacked.YEAR_REPORTED, y=stacked.value, hue=stacked.CRIME_TYPE, ax=ax)
plt.legend(loc='best', bbox_to_anchor=(1, 1))
plt.show()

# %%
death_or_harm = df[df['CRIME_TYPE'].isin(['ASSAULT', 'SEX CRIMES','HOMICIDE'])]

# %%
temp = pd.DataFrame(death_or_harm['ZIP_CODE'].value_counts().reset_index())

# %%
temp.columns = ['ZIP_CODE', 'TOTAL_COUNTS']
temp.head(2)
# Out:
#   ZIP_CODE  TOTAL_COUNTS
# 0    40203          7088
# 1    40211          6206

# %%
temp[temp['TOTAL_COUNTS']>3000]
# Out:
#    ZIP_CODE  TOTAL_COUNTS
# 0     40203          7088
# 1     40211          6206
# 2     40214          5812
# 3     40212          5541
# 4     40215          4897
# 5     40203          4799
# 6     40219          4558
# 7     40211          4380
# 8     40210          4172
# 9     40272          4039
# 10    40214          3869
# 11    40212          3737
# 12    40216          3730
# 13    40215          3598
# 14    40218          3393
# 15    40258          3312
# 16    40210          3078
# 17    40202          3063

# %%
# now stack and reset
stacked = crimes_reported_by_year.stack().reset_index().rename(columns={0:'value'})

# plot grouped bar chart
fig, ax = plt.subplots(figsize=(15,10))
sns.barplot(x=stacked.YEAR_REPORTED, y=stacked.value, hue=stacked.CRIME_TYPE, ax=ax)
plt.legend(loc='best', bbox_to_anchor=(1, 1))
plt.show()

# %%
plt.bar(temp[temp['TOTAL_COUNTS']>3000]['ZIP_CODE'].astype(int), temp[temp['TOTAL_COUNTS']>3000]['TOTAL_COUNTS'])
# temp[temp['TOTAL_COUNTS']>3000]['ZIP_CODE']
# Out:
# <Container object of 18 artists>

# %%
fig, ax = plt.subplots(figsize=(15,5))
sns.barplot(temp[temp['TOTAL_COUNTS']>3000]['ZIP_CODE'].astype(int), temp[temp['TOTAL_COUNTS']>3000]['TOTAL_COUNTS'], ci=None)
plt.title('Crimes(Count over 10 years > 3000) causing harm or death by Zip Code')
plt.xlabel('Zip code')
plt.ylabel('Crime Count')
plt.show()
